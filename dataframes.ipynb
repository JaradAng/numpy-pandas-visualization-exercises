# %%
import pandas as pd
import numpy as np
from pydataset import data

# %%
students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
#type(df)
#print(df)
df
# Out:
#        name  math  english  reading
# 0     Sally    98       72       95
# 1      Jane    98       88       81
# 2     Suzie    93       88       78
# 3     Billy    88       86       81
# 4       Ada    77       82       94
# 5      John    66       81       63
# 6    Thomas    69       95       77
# 7     Marie    77       88       65
# 8    Albert    65       95       84
# 9   Richard    61       96       72
# 10    Isaac    62       90       62
# 11     Alan    97       98       93

# %% [markdown]
# Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df['passing_english'] = df.english >70
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    98       72       95             True
# 1      Jane    98       88       81             True
# 2     Suzie    93       88       78             True
# 3     Billy    88       86       81             True
# 4       Ada    77       82       94             True
# 5      John    66       81       63             True
# 6    Thomas    69       95       77             True
# 7     Marie    77       88       65             True
# 8    Albert    65       95       84             True
# 9   Richard    61       96       72             True
# 10    Isaac    62       90       62             True
# 11     Alan    97       98       93             True

# %% [markdown]
# Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values(by='passing_english')

# sorted by index
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    98       72       95             True
# 1      Jane    98       88       81             True
# 2     Suzie    93       88       78             True
# 3     Billy    88       86       81             True
# 4       Ada    77       82       94             True
# 5      John    66       81       63             True
# 6    Thomas    69       95       77             True
# 7     Marie    77       88       65             True
# 8    Albert    65       95       84             True
# 9   Richard    61       96       72             True
# 10    Isaac    62       90       62             True
# 11     Alan    97       98       93             True

# %% [markdown]
# Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 4       Ada    77       82       94             True
# 11     Alan    97       98       93             True
# 8    Albert    65       95       84             True
# 3     Billy    88       86       81             True
# 10    Isaac    62       90       62             True
# 1      Jane    98       88       81             True
# 5      John    66       81       63             True
# 7     Marie    77       88       65             True
# 9   Richard    61       96       72             True
# 0     Sally    98       72       95             True
# 2     Suzie    93       88       78             True
# 6    Thomas    69       95       77             True

# %% [markdown]
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by = ['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    98       72       95             True
# 5      John    66       81       63             True
# 4       Ada    77       82       94             True
# 3     Billy    88       86       81             True
# 1      Jane    98       88       81             True
# 2     Suzie    93       88       78             True
# 7     Marie    77       88       65             True
# 10    Isaac    62       90       62             True
# 6    Thomas    69       95       77             True
# 8    Albert    65       95       84             True
# 9   Richard    61       96       72             True
# 11     Alan    97       98       93             True

# %% [markdown]
# Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df['overall_grade'] = round((df.english + df.math + df.reading) / 3, 2)

df
## wanted to make a column for overall grade
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    98       72       95             True          88.33
# 1      Jane    98       88       81             True          89.00
# 2     Suzie    93       88       78             True          86.33
# 3     Billy    88       86       81             True          85.00
# 4       Ada    77       82       94             True          84.33
# 5      John    66       81       63             True          70.00
# 6    Thomas    69       95       77             True          80.33
# 7     Marie    77       88       65             True          76.67
# 8    Albert    65       95       84             True          81.33
# 9   Richard    61       96       72             True          76.33
# 10    Isaac    62       90       62             True          71.33
# 11     Alan    97       98       93             True          96.00

# %% [markdown]
# Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# How many rows and columns are there?

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
mpg.rename(columns = {'cty': 'city'}, inplace=True)

# %%
mpg.rename(columns= {'hwy': 'highway'}, inplace=True)

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
# mpg['City_>_Hwy'] = mpg.city > mpg.highway
# mpg

## no cars with city higher than highway
#
#mpg.drop(columns=['City_>_Hwy'])

# %% [markdown]
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values(by='mileage_difference', ascending=False)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
#      highway fl       class  mileage_difference
# 107       36  c  subcompact                  12
# 223       41  d  subcompact                  12
# 1         29  p     compact                  11
# 229       29  p     midsize                  11
# 36        29  r     midsize                  11
# ..       ... ..         ...                 ...
# 80        17  r         suv                   3
# 138       17  r         suv                   3
# 177       17  r         suv                   2
# 152       17  r         suv                   2
# 204       17  r      pickup                   2
#
# [234 rows x 12 columns]

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
compacts = mpg['class'] == 'compact'
compacts =mpg[compacts]
compacts.sort_values(by= 'highway').head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference  average_mileage
# 220  compact                   7             19.5

# %%
compacts.sort_values(by = 'highway', ascending=False).head(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference  average_mileage
# 213  compact                  11             38.5

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway) / 2

mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# 2    compact                   8             25.0
# 3    compact                  11             25.5
# 4    compact                   9             25.5
# 5    compact                  10             21.0
# ..       ...                 ...              ...
# 230  midsize                   9             23.5
# 231  midsize                   8             25.0
# 232  midsize                  10             21.0
# 233  midsize                   8             22.0
# 234  midsize                   9             21.5
#
# [234 rows x 13 columns]

# %%
dodges = mpg[mpg.manufacturer == 'dodge' ]

dodges.sort_values(by= 'average_mileage').head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  average_mileage
# 70       12  e  pickup                   3             10.5

# %%
dodges.sort_values(by= 'average_mileage', ascending=False).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0

# %% [markdown]
# ## Exercise 3
#
# Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals = data('Mammals')

# %% [markdown]
# How many rows and columns are there?

# %%
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# What are the data types?

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mammals.info
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
mammals.sort_values(by='speed', ascending= False).head(1)

# wanted to try loc method
##mammals.loc[mammals.speed.idxmax()].weight
# Out:
# 55.0

# %% [markdown]
# What is the overal percentage of specials?

# %%
len_of_mammals = len(mammals)

len_of_mammals
# Out:
# 107

# %%
len_of_specials = len(mammals[mammals.specials == True])

# %%
percent_of_specials = round((len_of_specials / len_of_mammals) * 100, 2)

percent_of_specials
# Out:
# 9.35

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
len_of_hoppers = len(mammals[mammals.hoppers == True])

len_of_hoppers

hoppers = mammals[mammals.hoppers == True]

hoppers
# Out:
#      weight  speed  hoppers  specials
# 82    0.056   21.0     True     False
# 85    0.035   32.0     True     False
# 86    0.035   14.0     True     False
# 96    4.600   64.0     True     False
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 99    3.500   56.0     True     False
# 100   2.000   64.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False

# %%
median_speed = mammals.speed.median()

median_speed

faster_than_avg = hoppers[hoppers.speed > median_speed]
faster_than_avg = len(faster_than_avg)

faster_than_avg

percent_faster_hoppers = round((faster_than_avg / len_of_mammals) * 100, 2)

percent_faster_hoppers
# Out:
# 6.54
